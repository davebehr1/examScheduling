# %%
#each gen consists of a population of individuals
#each point is represented by a string of characters -> a chromosone

# %%
# 1) Randomly initialize populations p
# 2) Determine fitness of population
# 3) Untill convergence repeat:
#       a) Select parents from population
#       b) Crossover and generate new population
#       c) Perform mutation on new population
#       d) Calculate fitness for new population

# %%
import random

# %%
POPULATION_SIZE = 100
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
TARGET = "I love GeeksforGeeks"


#GENES = all low level pertubative hyper heuristics
#Swapping two randomly selected exams
#Swapping subsets of exams
#De-allocating exams
#Rescheduling exams
#Swapping timeslots of two randomly selected examinations


#TARGET = BEST SOLUTION

# %%
class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome  
        self.fitness = self.cal_fitness() 
  
    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 
  
    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 
  
    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''
  
        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):     
  
            # random probability   
            prob = random.random() 
  
            # if prob is less than 0.45, insert gene 
            # from parent 1  
            if prob < 0.45: 
                child_chromosome.append(gp1) 
  
            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 
  
            # otherwise insert random gene(mutate),  
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 
  
        # create new Individual(offspring) using  
        # generated chromosome for offspring 
        return Individual(child_chromosome) 
  
    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness

# %%
def main(): 
    global POPULATION_SIZE 
  
    #current generation 
    generation = 1
  
    found = False
    population = [] 
  
    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 
  
    while not found: 
  
        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 
  
        # if the individual having lowest fitness score ie.  
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break
  
        # Otherwise generate new offsprings for new generation 
        new_generation = [] 
  
        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 
  
        # From 50% of fittest population, Individuals  
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 
  
        population = new_generation 
  
        print("Generation: {}\tString: {}\tFitness: {}". 
              format(generation, 
              "".join(population[0].chromosome), 
              population[0].fitness)) 
  
        generation += 1
  
      
    print("Generation: {}\tString: {}\tFitness: {}". 
          format(generation, 
          "".join(population[0].chromosome), 
          population[0].fitness))

# %%
main()
# Out:
# Generation: 1	String: Pw1oveCsAy{jmvQ1k/.Z	Fitness: 17
# Generation: 2	String: Pw{ove sAy{jmrQ1k/.Z	Fitness: 16
# Generation: 3	String: Pw{ove sAy{jmrQ1k/.Z	Fitness: 16
# Generation: 4	String: Pw{ove sAy{jmrQ1k/.Z	Fitness: 16
# Generation: 5	String: Z]Kove eAE _b9QTk-kv	Fitness: 15
# Generation: 6	String: LwErve ws,psfo;Fp_ky	Fitness: 13
# Generation: 7	String: LwErve ws,psfo;Fp_ky	Fitness: 13
# Generation: 8	String: LwErve ws,psfo;Fp_ky	Fitness: 13
# Generation: 9	String: v Arve vs&ps0o[Fweky	Fitness: 12
# Generation: 10	String: v Arve vs&ps0o[Fweky	Fitness: 12
# Generation: 11	String: PLLove GeO%sfJDOw?ky	Fitness: 11
# Generation: 12	String: PLLove Gex%sfomOwe&[	Fitness: 10
# Generation: 13	String: PLLove Gex%sfomOwe&[	Fitness: 10
# Generation: 14	String: PLLove Gex%sfomOwe&[	Fitness: 10
# Generation: 15	String: PLlove Gexksf-rOwec]	Fitness: 8
# Generation: 16	String: PLlove Gexksf-rOwec]	Fitness: 8
# Generation: 17	String: PLlove Gexksf-rOwec]	Fitness: 8
# Generation: 18	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 19	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 20	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 21	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 22	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 23	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 24	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 25	String: P love Gexksfor=5ek]	Fitness: 5
# Generation: 26	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 27	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 28	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 29	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 30	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 31	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 32	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 33	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 34	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 35	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 36	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 37	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 38	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 39	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 40	String: L love Ge.ksforveek4	Fitness: 4
# Generation: 41	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 42	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 43	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 44	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 45	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 46	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 47	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 48	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 49	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 50	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 51	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 52	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 53	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 54	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 55	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 56	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 57	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 58	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 59	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 60	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 61	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 62	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 63	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 64	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 65	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 66	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 67	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 68	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 69	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 70	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 71	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 72	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 73	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 74	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 75	String: I love Ge ksfor%eeko	Fitness: 3
# Generation: 76	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 77	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 78	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 79	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 80	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 81	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 82	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 83	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 84	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 85	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 86	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 87	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 88	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 89	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 90	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 91	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 92	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 93	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 94	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 95	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 96	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 97	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 98	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 99	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 100	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 101	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 102	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 103	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 104	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 105	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 106	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 107	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 108	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 109	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 110	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 111	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 112	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 113	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 114	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 115	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 116	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 117	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 118	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 119	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 120	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 121	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 122	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 123	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 124	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 125	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 126	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 127	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 128	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 129	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 130	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 131	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 132	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 133	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 134	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 135	String: I love Geeksfor@eeko	Fitness: 2
# Generation: 136	String: I love GeeksforGeeko	Fitness: 1
# Generation: 137	String: I love GeeksforGeeko	Fitness: 1
# Generation: 138	String: I love GeeksforGeeko	Fitness: 1
# Generation: 139	String: I love GeeksforGeeko	Fitness: 1
# Generation: 140	String: I love GeeksforGeeko	Fitness: 1
# Generation: 141	String: I love GeeksforGeeko	Fitness: 1
# Generation: 142	String: I love GeeksforGeeko	Fitness: 1
# Generation: 143	String: I love GeeksforGeeko	Fitness: 1
# Generation: 144	String: I love GeeksforGeeko	Fitness: 1
# Generation: 145	String: I love GeeksforGeeko	Fitness: 1
# Generation: 146	String: I love GeeksforGeeko	Fitness: 1
# Generation: 147	String: I love GeeksforGeeko	Fitness: 1
# Generation: 148	String: I love GeeksforGeeko	Fitness: 1
# Generation: 149	String: I love GeeksforGeeko	Fitness: 1
# Generation: 150	String: I love GeeksforGeeko	Fitness: 1
# Generation: 151	String: I love GeeksforGeeko	Fitness: 1
